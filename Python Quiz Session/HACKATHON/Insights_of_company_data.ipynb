# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
# import seaborn as sns

dataset = pd.read_csv('https://raw.githubusercontent.com/Laxminarayen/Inceptz-Batch13-Analytics_and_Python/master/Hackathon/company.csv')
dataset
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %%
dataset.isna().sum()
# Out:
# Company     8
# Age        18
# Salary     24
# Place      14
# Country     0
# Gender      0
# dtype: int64

# %%
dataset[['Company','Place']] = dataset[['Company','Place']].fillna(value = 'Unkown')
dataset[['Age','Salary']] = dataset[['Age','Salary']].fillna(value = 0)

# %%
dataset.isna().sum()
# Out:
# Company    0
# Age        0
# Salary     0
# Place      0
# Country    0
# Gender     0
# dtype: int64

# %%
dataset['Company'] = dataset['Company'].str.replace('Congnizant','CTS')
dataset['Company'] = dataset['Company'].str.replace('Infosys Pvt Lmt','Infosys')
dataset['Company'] = dataset['Company'].str.replace('Tata Consultancy Services','TCS')

# %%
dataset.groupby(['Company']).Company.count()
# Out:
# Company
# CTS        38
# Infosys    47
# TCS        55
# Unkown      8
# Name: Company, dtype: int64

# %% [markdown]
# # range of salary offered in companies

# %%
sns.scatterplot(x=dataset['Company'],y=dataset['Salary'])

# %% [markdown]
# # rising criteria of salary with respect to age

# %%
sns.lineplot(x=dataset['Age'],y=dataset['Salary'])

# %%
dataset.groupby(['Country']).sum()
# Out:
#             Age    Salary  Gender
# Country
# India    3963.0  658746.0      33

# %% [markdown]
# # Distribution of the Salary

# %%
sns.distplot(dataset['Salary'])

# %%
sns.distplot(dataset['Age'])

# %%
sns.boxplot(x=dataset['Company'],y=dataset['Age'])

# %% [markdown]
# # population of people working in three companies

# %%
dataset.groupby('Company').size().plot(kind='bar')

# %%
sns.swarmplot(x=dataset['Age'],y=dataset['Place'])
